# %% [markdown]
# # Sesión 1
#
# Este archivo es para 2 cosas:
# 1. DFamiliarizarnos con Jupyter Notebook
# 2. Practicar Python

# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# ## Variables
#
# Las variables en Python son tipos de datos que tienen diferente forma
#
# - Numéricas
#     - Enteros
#     - Flotante
# - Cadenas de caracteres
# - Booleanos
# - Compuestos

# %%
nombre = "Ricardo"
edad = 46
es_estudiante = True
esta_activo = None

print(type(nombre))
print(type(edad))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "Ricardo"
edad = 46

print("Hola", nombre, "ya vi que tienes", edad, " años de edad")
# Out:
# Hola Ricardo ya vi que tienes 46  años de edad

# %% [markdown]
# En este punto, inicialicé el proyecto en Git

# %% [markdown]
# ## Algoritmo para calcular velocidad

# %%
distancia = int(input("Ingrese la distancia en kilómetros: "))
tiempo = int(input("Ingrese el tiempo en horas: "))

print("El dato distancia es de tipo: ", type(distancia))
print("El dato tiempo es de tipo: ", type(tiempo))

velocidad = distancia / tiempo

print("La velocidad promedio es:", velocidad)
# Out:
# El dato distancia es de tipo:  <class 'int'>
# El dato tiempo es de tipo:  <class 'int'>
# La velocidad promedio es: 40.0

# %% [markdown]
# Operadores

# %%
a = 4
b = 6

print(a + b)
print(a == b)
print(a < b)
print(a != b)
# Out:
# 10
# False
# True
# True

# %% [markdown]
# ## Entradas y salidas
